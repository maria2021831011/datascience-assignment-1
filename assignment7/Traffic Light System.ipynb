# %%
color=input("Enter(red, yellow, or green): ").lower()
if color=="red":
    print("Stop")
elif color=="yellow":
    print("Ready to go")
elif color=="green":
    print("Go")
else:
    print("Invalid color")
# Out:
# Ready to go
