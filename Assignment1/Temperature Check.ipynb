# %%
a=float(input("enter current temperature celcius"))
if a<10:
    print("It's too cold!")
elif a>=10 and a<=25:  
    print("It's cool outside")
else:
    print("It's hot outside!")
# Out:
# It's hot outside!
